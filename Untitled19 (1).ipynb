# %%
#import standard apis
import pandas
import numpy
import seaborn
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline           
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score
from sklearn import tree
from sklearn .naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from pylab import rcParams
rcParams['figure.figsize']=10,8
from sklearn import datasets,linear_model
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
#hide all the warnings in jupiter notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#import shoes_data.csv file
shoes_data=pandas.read_csv('C:/Users/dell/Desktop/shoes data.csv')

# %%
#check the titles of the data
shoes_data.head()
# Out:
#       Brand  Age   size  price quality comfort   duration   warrenty  rating  \
# 0      nike   20  large   3400    high     fit  24 months  12 months     4.5
# 1  woodland   25  large   4500    high     fit  18 months  12 months     3.5
# 2      bata    8  small   2800    high     fit  12 months  12 months     3.2
# 3   addidas   30  large   5000    high     fit  18 months  12 months     4.0
# 4      puma   35  large   2400    high     fit  12 months   6 months     3.9
#
#      offers   comment
# 0  0.05 off  positive
# 1   0.04off  positive
# 2   0.04off  positive
# 3   0.05off  positive
# 4   0.06off  positive

# %%
#mapping the comments data to ones and zeroes
shoes_data['comment']=shoes_data['comment'].map({'positive':1,'negative':0})

# %%
#spliting independent and dependent variables
shoes_data_x=shoes_data[['Brand','Age','size','price','quality','comfort','duration','warrenty','rating','offers']]
shoes_data_y=shoes_data[['comment']]

# %%
#split the train data and test data
x_train,x_test,y_train,y_test=train_test_split(shoes_data_x,shoes_data_y,test_size=0.20)

# %%
x_train
# Out:
#          Brand  Age    size  price quality comfort   duration   warrenty  \
# 9       reebok   21   large   5000    high     fit   8 months   6 months
# 5   seaandwear   42   large   1000    high     fit  18 months  12 months
# 10     paragon   15  medium    500     low   unfit  12 months   6 months
# 0         nike   20   large   3400    high     fit  24 months  12 months
# 7         fila   20   large   5000     low   unfit   6 months   6 months
# 14       spark   26   large   1600     low   unfit   8 months   6 months
# 1     woodland   25   large   4500    high     fit  18 months  12 months
# 6    leecooper   45   large   2000    high     fit  24 months  12 months
# 8      redtape   32   large   1500     low   unfit   6 months   6 months
# 12    roadster   29   large    400     low   unfit   6 months   6 months
# 2         bata    8   small   2800    high     fit  12 months  12 months
# 13      crocks   15  medium   2000    high     fit  12 months   6 months
#
# ...

# %%
#normalize the brand attribute
brand_encoder=preprocessing.LabelEncoder()

# %%
brand_encoder.fit(pandas.DataFrame(x_train['Brand']))
# Out:
# LabelEncoder()

# %%
x_train['Brand']=brand_encoder.transform(pandas.DataFrame(x_train[['Brand']]))

# %%
x_train
# Out:
#     Brand  Age    size  price quality comfort   duration   warrenty  rating  \
# 9       7   21   large   5000    high     fit   8 months   6 months     4.0
# 5       9   42   large   1000    high     fit  18 months  12 months     5.0
# 10      5   15  medium    500     low   unfit  12 months   6 months     4.0
# 0       4   20   large   3400    high     fit  24 months  12 months     4.5
# 7       2   20   large   5000     low   unfit   6 months   6 months     2.9
# 14     10   26   large   1600     low   unfit   8 months   6 months     2.2
# 1      11   25   large   4500    high     fit  18 months  12 months     3.5
# 6       3   45   large   2000    high     fit  24 months  12 months     3.4
# 8       6   32   large   1500     low   unfit   6 months   6 months     2.9
# 12      8   29   large    400     low   unfit   6 months   6 months     3.4
# 2       0    8   small   2800    high     fit  12 months  12 months     3.2
# ...

# %%
brand_scaler=StandardScaler()

# %%
brand_scaler.fit(pandas.DataFrame(x_train['Brand']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['Brand']]=brand_scaler.transform(pandas.DataFrame(x_train[['Brand']]))

# %%
x_train
# Out:
#        Brand  Age    size  price quality comfort   duration   warrenty  \
# 9   0.434524   21   large   5000    high     fit   8 months   6 months
# 5   1.013890   42   large   1000    high     fit  18 months  12 months
# 10 -0.144841   15  medium    500     low   unfit  12 months   6 months
# 0  -0.434524   20   large   3400    high     fit  24 months  12 months
# 7  -1.013890   20   large   5000     low   unfit   6 months   6 months
# 14  1.303572   26   large   1600     low   unfit   8 months   6 months
# 1   1.593255   25   large   4500    high     fit  18 months  12 months
# 6  -0.724207   45   large   2000    high     fit  24 months  12 months
# 8   0.144841   32   large   1500     low   unfit   6 months   6 months
# 12  0.724207   29   large    400     low   unfit   6 months   6 months
# 2  -1.593255    8   small   2800    high     fit  12 months  12 months
# 13 -1.303572   15  medium   2000    high     fit  12 months   6 months
#
#     rating    offers
# 9      4.0   0.04off
# ...

# %%
#normalize the age attribute
age_scaler=StandardScaler()
age_scaler.fit(pandas.DataFrame(x_train['Age']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['Age']]=age_scaler.transform(pandas.DataFrame(x_train[['Age']]))

# %%
x_train
# Out:
#        Brand       Age    size  price quality comfort   duration   warrenty  \
# 9   0.434524 -0.366933   large   5000    high     fit   8 months   6 months
# 5   1.013890  1.643222   large   1000    high     fit  18 months  12 months
# 10 -0.144841 -0.941263  medium    500     low   unfit  12 months   6 months
# 0  -0.434524 -0.462655   large   3400    high     fit  24 months  12 months
# 7  -1.013890 -0.462655   large   5000     low   unfit   6 months   6 months
# 14  1.303572  0.111675   large   1600     low   unfit   8 months   6 months
# 1   1.593255  0.015954   large   4500    high     fit  18 months  12 months
# 6  -0.724207  1.930387   large   2000    high     fit  24 months  12 months
# 8   0.144841  0.686005   large   1500     low   unfit   6 months   6 months
# 12  0.724207  0.398840   large    400     low   unfit   6 months   6 months
# 2  -1.593255 -1.611315   small   2800    high     fit  12 months  12 months
# ...

# %%
#normalize the size attribute
size_encoder=preprocessing.LabelEncoder()

# %%
size_encoder.fit(pandas.DataFrame(x_train['size']))
# Out:
# LabelEncoder()

# %%
x_train['size']=size_encoder.transform(pandas.DataFrame(x_train[['size']]))

# %%
x_train
# Out:
#        Brand       Age  size  price quality comfort   duration   warrenty  \
# 9   0.434524 -0.366933     0   5000    high     fit   8 months   6 months
# 5   1.013890  1.643222     0   1000    high     fit  18 months  12 months
# 10 -0.144841 -0.941263     1    500     low   unfit  12 months   6 months
# 0  -0.434524 -0.462655     0   3400    high     fit  24 months  12 months
# 7  -1.013890 -0.462655     0   5000     low   unfit   6 months   6 months
# 14  1.303572  0.111675     0   1600     low   unfit   8 months   6 months
# 1   1.593255  0.015954     0   4500    high     fit  18 months  12 months
# 6  -0.724207  1.930387     0   2000    high     fit  24 months  12 months
# 8   0.144841  0.686005     0   1500     low   unfit   6 months   6 months
# 12  0.724207  0.398840     0    400     low   unfit   6 months   6 months
# 2  -1.593255 -1.611315     2   2800    high     fit  12 months  12 months
# 13 -1.303572 -0.941263     1   2000    high     fit  12 months   6 months
#
# ...

# %%
#normalize the price attribute
price_scaler=StandardScaler()
price_scaler.fit(pandas.DataFrame(x_train['price']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['price']]=price_scaler.transform(pandas.DataFrame(x_train[['price']]))

# %%
x_train
# Out:
#        Brand       Age  size     price quality comfort   duration   warrenty  \
# 9   0.434524 -0.366933     0  1.587389    high     fit   8 months   6 months
# 5   1.013890  1.643222     0 -0.927286    high     fit  18 months  12 months
# 10 -0.144841 -0.941263     1 -1.241621     low   unfit  12 months   6 months
# 0  -0.434524 -0.462655     0  0.581519    high     fit  24 months  12 months
# 7  -1.013890 -0.462655     0  1.587389     low   unfit   6 months   6 months
# 14  1.303572  0.111675     0 -0.550085     low   unfit   8 months   6 months
# 1   1.593255  0.015954     0  1.273054    high     fit  18 months  12 months
# 6  -0.724207  1.930387     0 -0.298618    high     fit  24 months  12 months
# 8   0.144841  0.686005     0 -0.612952     low   unfit   6 months   6 months
# 12  0.724207  0.398840     0 -1.304488     low   unfit   6 months   6 months
# 2  -1.593255 -1.611315     2  0.204317    high     fit  12 months  12 months
# ...

# %%
#normalise the quality attribute
quality_encoder=preprocessing.LabelEncoder()

# %%
quality_encoder.fit(pandas.DataFrame(x_train['quality']))
# Out:
# LabelEncoder()

# %%
x_train['quality']=quality_encoder.transform(pandas.DataFrame(x_train[['quality']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality comfort   duration   warrenty  \
# 9   0.434524 -0.366933     0  1.587389        0     fit   8 months   6 months
# 5   1.013890  1.643222     0 -0.927286        0     fit  18 months  12 months
# 10 -0.144841 -0.941263     1 -1.241621        1   unfit  12 months   6 months
# 0  -0.434524 -0.462655     0  0.581519        0     fit  24 months  12 months
# 7  -1.013890 -0.462655     0  1.587389        1   unfit   6 months   6 months
# 14  1.303572  0.111675     0 -0.550085        1   unfit   8 months   6 months
# 1   1.593255  0.015954     0  1.273054        0     fit  18 months  12 months
# 6  -0.724207  1.930387     0 -0.298618        0     fit  24 months  12 months
# 8   0.144841  0.686005     0 -0.612952        1   unfit   6 months   6 months
# 12  0.724207  0.398840     0 -1.304488        1   unfit   6 months   6 months
# 2  -1.593255 -1.611315     2  0.204317        0     fit  12 months  12 months
# ...

# %%
#normalise the comfort attribute
comfort_encoder=preprocessing.LabelEncoder()

# %%
comfort_encoder.fit(pandas.DataFrame(x_train['comfort']))
# Out:
# LabelEncoder()

# %%
x_train['comfort']=comfort_encoder.transform(pandas.DataFrame(x_train[['comfort']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality  comfort   duration  \
# 9   0.434524 -0.366933     0  1.587389        0        0   8 months
# 5   1.013890  1.643222     0 -0.927286        0        0  18 months
# 10 -0.144841 -0.941263     1 -1.241621        1        1  12 months
# 0  -0.434524 -0.462655     0  0.581519        0        0  24 months
# 7  -1.013890 -0.462655     0  1.587389        1        1   6 months
# 14  1.303572  0.111675     0 -0.550085        1        1   8 months
# 1   1.593255  0.015954     0  1.273054        0        0  18 months
# 6  -0.724207  1.930387     0 -0.298618        0        0  24 months
# 8   0.144841  0.686005     0 -0.612952        1        1   6 months
# 12  0.724207  0.398840     0 -1.304488        1        1   6 months
# 2  -1.593255 -1.611315     2  0.204317        0        0  12 months
# 13 -1.303572 -0.941263     1 -0.298618        0        0  12 months
#
#      warrenty  rating    offers
# 9    6 months     4.0   0.04off
# ...

# %%
#normalise the duration attribute
duration_encoder=preprocessing.LabelEncoder()

# %%
duration_encoder.fit(pandas.DataFrame(x_train['duration']))
# Out:
# LabelEncoder()

# %%
x_train[['duration']]=duration_encoder.transform(pandas.DataFrame(x_train[['duration']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality  comfort  duration   warrenty  \
# 9   0.434524 -0.366933     0  1.587389        0        0         4   6 months
# 5   1.013890  1.643222     0 -0.927286        0        0         1  12 months
# 10 -0.144841 -0.941263     1 -1.241621        1        1         0   6 months
# 0  -0.434524 -0.462655     0  0.581519        0        0         2  12 months
# 7  -1.013890 -0.462655     0  1.587389        1        1         3   6 months
# 14  1.303572  0.111675     0 -0.550085        1        1         4   6 months
# 1   1.593255  0.015954     0  1.273054        0        0         1  12 months
# 6  -0.724207  1.930387     0 -0.298618        0        0         2  12 months
# 8   0.144841  0.686005     0 -0.612952        1        1         3   6 months
# 12  0.724207  0.398840     0 -1.304488        1        1         3   6 months
# 2  -1.593255 -1.611315     2  0.204317        0        0         0  12 months
# ...

# %%
warrenty_encoder=preprocessing.LabelEncoder()

# %%
warrenty_encoder.fit(pandas.DataFrame(x_train['warrenty']))
# Out:
# LabelEncoder()

# %%
x_train['warrenty']=warrenty_encoder.transform(pandas.DataFrame(x_train[['warrenty']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality  comfort  duration  warrenty  \
# 9   0.434524 -0.366933     0  1.587389        0        0         4         1
# 5   1.013890  1.643222     0 -0.927286        0        0         1         0
# 10 -0.144841 -0.941263     1 -1.241621        1        1         0         1
# 0  -0.434524 -0.462655     0  0.581519        0        0         2         0
# 7  -1.013890 -0.462655     0  1.587389        1        1         3         1
# 14  1.303572  0.111675     0 -0.550085        1        1         4         1
# 1   1.593255  0.015954     0  1.273054        0        0         1         0
# 6  -0.724207  1.930387     0 -0.298618        0        0         2         0
# 8   0.144841  0.686005     0 -0.612952        1        1         3         1
# 12  0.724207  0.398840     0 -1.304488        1        1         3         1
# 2  -1.593255 -1.611315     2  0.204317        0        0         0         0
# ...

# %%
#normalise the rating attribute
ratings_encoder=preprocessing.LabelEncoder()

# %%
ratings_encoder.fit(pandas.DataFrame(x_train['rating']))
# Out:
# LabelEncoder()

# %%
x_train['rating']=ratings_encoder.transform(pandas.DataFrame(x_train[['rating']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality  comfort  duration  warrenty  \
# 9   0.434524 -0.366933     0  1.587389        0        0         4         1
# 5   1.013890  1.643222     0 -0.927286        0        0         1         0
# 10 -0.144841 -0.941263     1 -1.241621        1        1         0         1
# 0  -0.434524 -0.462655     0  0.581519        0        0         2         0
# 7  -1.013890 -0.462655     0  1.587389        1        1         3         1
# 14  1.303572  0.111675     0 -0.550085        1        1         4         1
# 1   1.593255  0.015954     0  1.273054        0        0         1         0
# 6  -0.724207  1.930387     0 -0.298618        0        0         2         0
# 8   0.144841  0.686005     0 -0.612952        1        1         3         1
# 12  0.724207  0.398840     0 -1.304488        1        1         3         1
# 2  -1.593255 -1.611315     2  0.204317        0        0         0         0
# ...

# %%
#normalise the offers attribute
offers_encoder=preprocessing.LabelEncoder()

# %%
offers_encoder.fit(pandas.DataFrame(x_train['offers']))
# Out:
# LabelEncoder()

# %%
x_train['offers']=offers_encoder.transform(pandas.DataFrame(x_train[['offers']]))

# %%
x_train
# Out:
#        Brand       Age  size     price  quality  comfort  duration  warrenty  \
# 9   0.434524 -0.366933     0  1.587389        0        0         4         1
# 5   1.013890  1.643222     0 -0.927286        0        0         1         0
# 10 -0.144841 -0.941263     1 -1.241621        1        1         0         1
# 0  -0.434524 -0.462655     0  0.581519        0        0         2         0
# 7  -1.013890 -0.462655     0  1.587389        1        1         3         1
# 14  1.303572  0.111675     0 -0.550085        1        1         4         1
# 1   1.593255  0.015954     0  1.273054        0        0         1         0
# 6  -0.724207  1.930387     0 -0.298618        0        0         2         0
# 8   0.144841  0.686005     0 -0.612952        1        1         3         1
# 12  0.724207  0.398840     0 -1.304488        1        1         3         1
# 2  -1.593255 -1.611315     2  0.204317        0        0         0         0
# ...

# %%
#y_train['comment']=y_train['comment'].map({'positive':1,'negative':0})

# %%
#y_train

# %%
x_train_original=x_train
x_train=x_train.values
y_train=y_train.values

# %%
#create object of logistic regression
logistic_regression=LogisticRegression()

# %%
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
x_test
# Out:
#       Brand  Age   size  price quality comfort   duration   warrenty  rating  \
# 11   sports   27  large    800     low   unfit   6 months   6 months     3.3
# 4      puma   35  large   2400    high     fit  12 months   6 months     3.9
# 3   addidas   30  large   5000    high     fit  18 months  12 months     4.0
#
#      offers
# 11  0.07off
# 4   0.06off
# 3   0.05off

# %%
#normalise the brand attribute
brand_encoder=preprocessing.LabelEncoder()

# %%
brand_encoder.fit(pandas.DataFrame(x_test['Brand']))
# Out:
# LabelEncoder()

# %%
x_test[['Brand']]=brand_encoder.transform(pandas.DataFrame(x_test[['Brand']]))

# %%
x_test
# Out:
#     Brand  Age   size  price quality comfort   duration   warrenty  rating  \
# 11      2   27  large    800     low   unfit   6 months   6 months     3.3
# 4       1   35  large   2400    high     fit  12 months   6 months     3.9
# 3       0   30  large   5000    high     fit  18 months  12 months     4.0
#
#      offers
# 11  0.07off
# 4   0.06off
# 3   0.05off

# %%
#normalise the age attribute
age_encoder=preprocessing.LabelEncoder()

# %%
age_encoder.fit(pandas.DataFrame(x_test['Age']))
# Out:
# LabelEncoder()

# %%
x_test[['Age']]=age_encoder.transform(pandas.DataFrame(x_test[['Age']]))

# %%
#normalise the size attribute
size_encoder=preprocessing.LabelEncoder()

# %%
size_encoder.fit(pandas.DataFrame(x_test['size']))
# Out:
# LabelEncoder()

# %%
x_test[['size']]=size_encoder.transform(pandas.DataFrame(x_test[['size']]))

# %%
#normalise the price attribute
price_encoder=preprocessing.LabelEncoder()

# %%
price_encoder.fit(pandas.DataFrame(x_test['price']))
# Out:
# LabelEncoder()

# %%
x_test[['price']]=price_encoder.transform(pandas.DataFrame(x_test[['price']]))

# %%
#normalise the quality attribute
quality_encoder=preprocessing.LabelEncoder()

# %%
quality_encoder.fit(pandas.DataFrame(x_test['quality']))
# Out:
# LabelEncoder()

# %%
x_test[['quality']]=quality_encoder.transform(pandas.DataFrame(x_test[['quality']]))

# %%
#normalise the comfort attribute
comfort_encoder=preprocessing.LabelEncoder()

# %%
comfort_encoder.fit(pandas.DataFrame(x_test['comfort']))
# Out:
# LabelEncoder()

# %%
x_test[['comfort']]=comfort_encoder.transform(pandas.DataFrame(x_test[['comfort']]))

# %%
#normalise the duration attribute
duration_encoder=preprocessing.LabelEncoder()

# %%
duration_encoder.fit(pandas.DataFrame(x_test['duration']))
# Out:
# LabelEncoder()

# %%
x_test[['duration']]=duration_encoder.transform(pandas.DataFrame(x_test[['duration']]))

# %%
warrenty_encoder=preprocessing.LabelEncoder()

# %%
warrenty_encoder.fit(pandas.DataFrame(x_test['warrenty']))
# Out:
# LabelEncoder()

# %%
x_test[['warrenty']]=warrenty_encoder.transform(pandas.DataFrame(x_test[['warrenty']]))

# %%
#normalise the rating attribute
ratings_encoder=preprocessing.LabelEncoder()

# %%
ratings_encoder.fit(pandas.DataFrame(x_test['rating']))
# Out:
# LabelEncoder()

# %%
x_test[['rating']]=ratings_encoder.transform(pandas.DataFrame(x_test[['rating']]))

# %%
#normalise the offers attribute
offers_encoder=preprocessing.LabelEncoder()

# %%
offers_encoder.fit(pandas.DataFrame(x_test['offers']))
# Out:
# LabelEncoder()

# %%
x_test[['offers']]=offers_encoder.transform(pandas.DataFrame(x_test[['offers']]))

# %%
x_test
# Out:
#     Brand  Age  size  price  quality  comfort  duration  warrenty  rating  \
# 11      2    0     0      0        1        1         2         1       0
# 4       1    2     0      1        0        0         0         1       1
# 3       0    1     0      2        0        0         1         0       2
#
#     offers
# 11       2
# 4        1
# 3        0

# %%
#y_test['comment']=y_test['comment'].map({'positive':1,'negative':0})

# %%
#y_test

# %%
y_pred=logistic_regression.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 1], dtype=int64)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
#to check accuracy using decision tree 
decision_tree=tree.DecisionTreeClassifier()

# %%
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred=decision_tree.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
#to check accuracy using naive_bayes
naive_bayes=GaussianNB()

# %%
naive_bayes.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred=naive_bayes.predict(x_test)
y_pred_prob=naive_bayes.predict_proba(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
#to check accuracy using random forest
random_forest=RandomForestClassifier()

# %%
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred=random_forest.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
#to check the accuracy of r2 model
print(r2_score(y_test,y_pred))
# Out:
# 1.0
